# %% [markdown]
# (homage)=
# # Homage
#
# > *From the point of view of form, the `arche`type of all the arts is the art of the musician - Oscar Wilde*
#
#           1. f(t)
#                 \
#      2. S(t) -> 4. y:h'(t)=0;t(X'X)X'Y -> 5. b -> 6. SV'
#                 /
#                 3. h(t)
#
# ## Allegory
#
# ### Inherited fetters, $\mu$ (text)
# - $f(t)$ _Challenges_. Life including parts unknown in the tails (entire harmonic series) will throw things at you without any prejudice, as if `randomly` from a probability density function
# - $S(t)$ _Skills_. **Charity** of our forbears & our duty to others (ii-V7-i contain entire series here). Our cumulative heritage hands us an approach out of the spirit of music: what we are handed `displaces` us from the root to `ii`. And our forbears offer a step-wise, tried & tasted, well-trodden journey "back" home: `ii-V7-i`
# - $h(t)$ _Tools_. No quick home-cuming or path of least resistance. Rather, an obstacle-course that tests your strength, resilience, and build your muscle, bone, stamina, as well as emotional tension: your libido and drive is now like a dammed river, which builds a reservoir for future energy needs. Modes-qualities-relatives are the tools that create context for future surprises, tension, release
#
# ### Dancing in chains, $\sigma$ (context)
# - $(X’X)^T \cdot X’Y$ _Agency_. **Hope** is placed in you by the agent-less masses. They understand that with all the tension in the bow that you've accrued, your banks run over; your cup runneth over; you can help them shoot for distant goals
#
# ### Born to etiquette , $\%$ (pretext)
# - $\beta$ _Flow_. With an overflow of parameters and tools, they'll be able to leverage STEAM
# - $SV’$ _Undiminishing_. **Faith** that marginal utility from modal-quality-relative interchange will grow endlessly . GRIP

# %% [markdown]
# ```{margin}
#
# <Details>
#    <Summary> </Summary>
#
#    - *Genealogy of morality*
#    - *Tunakoberaku gha nga mwenewo nali neinhira ku matama*
#    - *Awononeire ekiwulu*
#    - *Do not kill the messenger*
#    - *Endovu bakivuma obutako engezirawo*
#       - *European claims to originality couldn't be challenged by Africans since they were far more powerful*
#
# </Details>

# %% [markdown]
# ## Essay
#
# To visualize your framework using graphs, statistical functions, and LaTeX, we can break down each element and represent it with appropriate mathematical and graphical tools. Here's a structured approach:
#
# ### 1. $ f(t) $ - Challenges
#
# This represents the random challenges life throws at us, akin to sampling from a probability distribution.
#
# **Graphical Representation:**
# - We can use a probability density function (PDF) to represent $ f(t) $. A common choice could be the normal distribution, but we can generalize it to any distribution.
#
# **LaTeX Representation:**
# $ f(t) = P(T \leq t) $
#
# **Python Code for Visualization:**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Time variable
t = np.linspace(-3, 3, 1000)
# Probability density function
pdf = norm.pdf(t)

plt.figure(figsize=(10, 6))
plt.plot(t, pdf, label='$f(t)$')
plt.title('Challenges $f(t)$ as a Probability Density Function')
plt.xlabel('Time')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 2. $ S(t) $ - Skills
#
# Skills and resilience passed down from forebears, represented as a cumulative distribution function (CDF) or a survival function.
#
# **Graphical Representation:**
# - The survival function $ S(t) $ can be depicted using a CDF.
#
# **LaTeX Representation:**
# $ S(t) = 1 - F(t) $
#
# **Python Code for Visualization:**

# %%
# Survival function
cdf = norm.cdf(t)
survival_function = 1 - cdf

plt.figure(figsize=(10, 6))
plt.plot(t, survival_function, label='$S(t)$', color='orange')
plt.title('Skills $S(t)$ as a Survival Function')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. $ h(t) $ - Tools
#
# Tools represent the tension and strength built from "restraint," visualized as a function that grows over time, possibly an exponential or logistic function.
#
# **Graphical Representation:**
# - An exponential growth function $ h(t) $.
#
# **LaTeX Representation:**
# $ h(t) = e^{\lambda t} $
#
# **Python Code for Visualization:**

# %%
# Exponential growth function
lambda_ = 0.5
h_t = np.exp(lambda_ * t)

plt.figure(figsize=(10, 6))
plt.plot(t, h_t, label='$h(t)$', color='green')
plt.title('Tools $h(t)$ as an Exponential Growth Function')
plt.xlabel('Time')
plt.ylabel('Growth')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4. $ (X'X)^T \cdot X'Y $ - Agency
#
# Agency represented by the product of matrices, showing the accumulation of skills and tools over time.
#
# **LaTeX Representation:**
# $ (X'X)^T \cdot X'Y $
#
# **Python Code for Visualization:**

# %%
import numpy as np

# Example matrix X and Y
X = np.array([[1, 2], [3, 4], [5, 6]])
Y = np.array([[1], [2], [3]])

# Matrix product
agency = np.dot(np.dot(X.T, X).T, np.dot(X.T, Y))

# Display the result
print("Agency (X'X)^T \cdot X'Y =\n", agency)
# Out:
# Agency (X'X)^T \cdot X'Y =
#  [[2002]
#  [2536]]
# <>:11: SyntaxWarning: invalid escape sequence '\c'
# <>:11: SyntaxWarning: invalid escape sequence '\c'
# /var/folders/z3/nwmg00j178vfczmb9nk9487h0000gn/T/ipykernel_2870/4156088341.py:11: SyntaxWarning: invalid escape sequence '\c'
#   print("Agency (X'X)^T \cdot X'Y =\n", agency)

# %% [markdown]
# To address the representation of $\beta$ (Flow) and reflect the length of the vector rather than redundancy, we will calculate and visualize the magnitude of the beta coefficients. This can be done by plotting the values of the beta coefficients and indicating their significance.
#
# ### 5. $\beta $ - Flow
#
# Flow represented by beta coefficients in a regression model, showing the relationship between inputs and outputs.
#
# **LaTeX Representation:**
# $\beta = (X'X)^{-1}X'Y $
#
# **Python Code for Visualization:**

# %%
 
import numpy as np
import matplotlib.pyplot as plt

# Example matrix X and Y
X = np.array([[1, 2], [3, 4], [5, 6]])
Y = np.array([[1], [2], [3]])

# Calculate beta coefficients
beta = np.linalg.inv(X.T @ X) @ X.T @ Y

# Compute the length (magnitude) of the beta vector
beta_magnitude = np.linalg.norm(beta)

# Plot beta coefficients
plt.figure(figsize=(10, 6))
plt.bar(range(len(beta)), beta.flatten(), color='blue', alpha=0.7)
plt.title('Beta Coefficients (Flow)')
plt.xlabel('Coefficient Index')
plt.ylabel('Coefficient Value')
plt.axhline(0, color='black', linewidth=0.5)
plt.grid(True)
plt.show()

# Display the magnitude of the beta vector
print(f"Magnitude of beta vector: {beta_magnitude:.2f}")
# Out:
# Magnitude of beta vector: 0.50

# %% [markdown]
# #### Combined Visualization with Edited $\beta$  Representation
#
# Integrating this improved visualization into the combined framework:

# %%
fig, axs = plt.subplots(3, 2, figsize=(15, 15))

# Plot f(t)
axs[0, 0].plot(t, pdf, label='$f(t)$')
axs[0, 0].set_title('Challenges $f(t)$ as a PDF')
axs[0, 0].set_xlabel('Time')
axs[0, 0].set_ylabel('Probability Density')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Plot S(t)
axs[0, 1].plot(t, survival_function, label='$S(t)$', color='orange')
axs[0, 1].set_title('Skills $S(t)$ as a Survival Function')
axs[0, 1].set_xlabel('Time')
axs[0, 1].set_ylabel('Survival Probability')
axs[0, 1].legend()
axs[0, 1].grid(True)

# Plot h(t)
axs[1, 0].plot(t, h_t, label='$h(t)$', color='green')
axs[1, 0].set_title('Tools $h(t)$ as an Exponential Growth Function')
axs[1, 0].set_xlabel('Time')
axs[1, 0].set_ylabel('Growth')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Display agency calculation
axs[1, 1].text(0.1, 0.5, f"Agency:\n$(X'X)^T \cdot X'Y$ =\n{agency}", fontsize=12, va='center')
axs[1, 1].set_title('Agency Calculation')
axs[1, 1].axis('off')

# Plot beta coefficients
axs[2, 0].bar(range(len(beta)), beta.flatten(), color='blue', alpha=0.7)
axs[2, 0].set_title('Beta Coefficients (Flow)')
axs[2, 0].set_xlabel('Coefficient Index')
axs[2, 0].set_ylabel('Coefficient Value')
axs[2, 0].axhline(0, color='black', linewidth=0.5)
axs[2, 0].grid(True)

# Display the magnitude of the beta vector
beta_magnitude_text = f"Magnitude of beta vector: {beta_magnitude:.2f}"
axs[2, 1].text(0.1, 0.5, beta_magnitude_text, fontsize=12, va='center')
axs[2, 1].set_title('Flow Calculation (Magnitude)')
axs[2, 1].axis('off')

# Display SVD results
axs[2, 1].text(0.1, 0.5, f"Undiminishing Utility (SVD):\n$X = U \\Sigma V'$\nU =\n{U}\nSigma =\n{sigma}\nV' =\n{Vt}", fontsize=12, va='center')
axs[2, 1].set_title('Undiminishing Utility (SVD)')
axs[2, 1].axis('off')

plt.tight_layout()
plt.show()
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\c'
# <>:28: SyntaxWarning: invalid escape sequence '\c'
# /var/folders/z3/nwmg00j178vfczmb9nk9487h0000gn/T/ipykernel_2870/3770563895.py:28: SyntaxWarning: invalid escape sequence '\c'
#   axs[1, 1].text(0.1, 0.5, f"Agency:\n$(X'X)^T \cdot X'Y$ =\n{agency}", fontsize=12, va='center')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 47
#      44 axs[2, 1].axis('off')
#      46 # Display SVD results
# ---> 47 axs[2, 1].text(0.1, 0.5, f"Undiminishing Utility (SVD):\n$X = U \\Sigma V'$\nU =\n{U}\nSigma =\n{sigma}\nV' =\n{Vt}", fontsize=12, va='center')
#      48 axs[2, 1].set_title('Undiminishing Utility (SVD)')
#      49 axs[2, 1].axis('off')
#
# NameError: name 'U' is not defined
